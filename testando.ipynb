# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("novo_relatorio.csv", header=None)

# Remova espaços desnecessários das células
dataset = dataset.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Salve o arquivo CSV corrigido
dataset.to_csv('novo_relatorio.csv', index=False, header=False)

dataset
# Out:
# C:\Users\bruns\AppData\Local\Temp\ipykernel_13776\2550004795.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   dataset = dataset.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#                                                       0                1  \
# 0                                                TÍTULO  TIPO_DE_SERVIÇO
# 1     Relatório 201900989 - Aplicação de recursos fe...        Avaliação
# 2     Relatório 1594386 - Aquisição de caminhões, tr...        Avaliação
# 3     Relatório 1557120 - Licitações realizadas pela...        Avaliação
# 4     Relatório 1354457 - Obra de reforma no Hospita...         Apuração
# ...                                                 ...              ...
# 1196  Relatório de Avaliação nº 907060 - Superintend...        Avaliação
# 1197  Relatorio de Avaliação n.º 943375 HFI - Anális...        Avaliação
# 1198  Verificação do cumprimento das obrigações prev...        Avaliação
# 1199  Relatório de Avaliação da Segurança e Privacid...        Avaliação
# 1200  Relatório de Apuração nº 832174 - Superintendê...         Apuração
#
#                                      2                                3  \
# 0                   GRUPO_DE_ATIVIDADE                    LINHA_DE_AÇÃO
# 1                               Outros  Auditoria Interna Governamental
# 2     Análise de Alertas de Licitações  Auditoria Interna Governamental
# 3     Análise de Alertas de Licitações  Auditoria Interna Governamental
# 4                                  NaN  Auditoria Interna Governamental
# ...                                ...                              ...
# 1196                            Outros  Auditoria interna governamental
# 1197                            Outros  Auditoria interna governamental
# 1198                            Outros  Auditoria interna governamental
# 1199                            Outros  Auditoria interna governamental
# 1200                            Outros  Auditoria interna governamental
#
#                                   4             5  \
# 0     AVALIAÇÃO_DE_POLÍTICA_PÚBLICA  PUBLICADO_EM
# 1                               Sim    26/06/2024
# 2                               Sim    21/06/2024
# 3                               Não    18/06/2024
# 4                               Não    17/06/2024
# ...                             ...           ...
# 1196                            Não    08/03/2022
# 1197                            Não    08/03/2022
# 1198                            Sim    25/02/2022
# 1199                            Sim    25/02/2022
# 1200                            Não    24/02/2022
#
#                                                       6
# 0                                           LOCALIDADES
# 1                                            Aracaju/SE
# 2                                           Brasília/DF
# 3     Porto Velho/RO, Belém/PA, Natal/RN, João Pesso...
# 4                                     Rio de Janeiro/RJ
# ...                                                 ...
# 1196                                 Mato Grosso do Sul
# 1197                                  Rio de Janeiro/RJ
# 1198                                        Brasília/DF
# 1199                                        Brasília/DF
# 1200                                  Patos de Minas/MG
#
# [1201 rows x 7 columns]
