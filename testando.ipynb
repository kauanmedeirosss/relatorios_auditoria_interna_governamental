# %%
import pandas as pd
import re
import numpy as np

dataset = pd.read_csv("novo_relatorio.csv")
dataset
# Out:
#                                                  TÍTULO TIPO_DE_SERVIÇO  \
# 0     Relatório 201900989 - Aplicação de recursos fe...       Avaliação
# 1     Relatório 1594386 - Aquisição de caminhões, tr...       Avaliação
# 2     Relatório 1557120 - Licitações realizadas pela...       Avaliação
# 3     Relatório 1354457 - Obra de reforma no Hospita...        Apuração
# 4     Relatório 1110378 - Aquisição de insumos pelo ...       Avaliação
# ...                                                 ...             ...
# 1633  Relatório de Avaliação 201902786 - Avaliação d...       Avaliação
# 1634  Relatório de Auditoria nº 840817 - Avaliação d...       Avaliação
# 1635  Relatório de Avaliação nº 903226 - Ministério ...       Avaliação
# 1636  Relatório de Avaliação nº 904397 - Prefeitura ...       Avaliação
# 1637  Relatório de Avaliação nº 824726 - Subsecretar...       Avaliação
#
#                                 GRUPO_DE_ATIVIDADE  \
# ...

# %%
print(dataset.columns)
# Out:
# Index(['TÍTULO', 'TIPO_DE_SERVIÇO', 'GRUPO_DE_ATIVIDADE', 'LINHA_DE_AÇÃO',
#        'AVALIAÇÃO_DE_POLÍTICA_PÚBLICA', 'PUBLICADO_EM', 'LOCALIDADES'],
#       dtype='object')

# %%
gata = dataset["AVALIAÇÃO_DE_POLÍTICA_PÚBLICA"].value_counts()
gata
# Out:
# AVALIAÇÃO_DE_POLÍTICA_PÚBLICA
# Não                                1295
# Sim                                 328
# \tNão                                 5
# Não\t                                 1
# Auditoria interna governamental       1
# Name: count, dtype: int64
