# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv("novo_relatorio.csv", header=None)

# Remova espaços desnecessários das células
dataset = dataset.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Salve o arquivo CSV corrigido
dataset.to_csv('novo_relatorio.csv', index=False, header=False)

dataset
# Out:
# C:\Users\bruns\AppData\Local\Temp\ipykernel_11128\2550004795.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   dataset = dataset.applymap(lambda x: x.strip() if isinstance(x, str) else x)
#                                                       0                1  \
# 0                                                TÍTULO  TIPO_DE_SERVIÇO
# 1     Relatório 201900989 - Aplicação de recursos fe...        Avaliação
# 2     Relatório 1594386 - Aquisição de caminhões, tr...        Avaliação
# 3     Relatório 1557120 - Licitações realizadas pela...        Avaliação
# 4     Relatório 1354457 - Obra de reforma no Hospita...         Apuração
# ...                                                 ...              ...
# 1296  RELATÓRIO DE APURAÇÃO 940861 - Administração R...         Apuração
# 1297  Relatório nº 919056 - Eletrobras - AAC 2021 (E...        Avaliação
# 1298  Fiscalização em Entes Federativos – FEF V07 - ...         Apuração
# 1299  Fiscalização em Entes Federativos – FEF V07 - ...         Apuração
# 1300  Fiscalização em Entes Federativos – FEF V07 - ...         Apuração
#
#                                            2                                3  \
# 0                         GRUPO_DE_ATIVIDADE                    LINHA_DE_AÇÃO
# 1                                     Outros  Auditoria Interna Governamental
# 2           Análise de Alertas de Licitações  Auditoria Interna Governamental
# 3           Análise de Alertas de Licitações  Auditoria Interna Governamental
# 4                                        NaN  Auditoria Interna Governamental
# ...                                      ...                              ...
# 1296                                  Outros  Auditoria interna governamental
# 1297  Avaliação da Prestação Anual de Contas  Auditoria interna governamental
# 1298       Fiscalização de Entes Federativos  Auditoria Interna Governamental
# 1299       Fiscalização de Entes Federativos  Auditoria Interna Governamental
# 1300       Fiscalização de Entes Federativos  Auditoria Interna Governamental
#
#                                   4             5  \
# 0     AVALIAÇÃO_DE_POLÍTICA_PÚBLICA  PUBLICADO_EM
# 1                               Sim    26/06/2024
# 2                               Sim    21/06/2024
# 3                               Não    18/06/2024
# 4                               Não    17/06/2024
# ...                             ...           ...
# 1296                            Não    14/01/2022
# 1297                            Não    14/01/2022
# 1298                            Não    14/01/2022
# 1299                            Não    13/01/2022
# 1300                            Não    13/01/2022
#
#                                                       6
# 0                                           LOCALIDADES
# 1                                            Aracaju/SE
# 2                                           Brasília/DF
# 3     Porto Velho/RO, Belém/PA, Natal/RN, João Pesso...
# 4                                     Rio de Janeiro/RJ
# ...                                                 ...
# 1296                                         Aracaju/SE
# 1297                                     Rio de Janeiro
# 1298                                           Pains/MG
# 1299                                        Claraval/MG
# 1300                                        Ninheira/MG
#
# [1301 rows x 7 columns]
